# %% [markdown]
# <a href="https://colab.research.google.com/github/bug-hunter333/AI_ML_essentials/blob/main/Multivariate_analysis_for_outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Multivariate Analysis for outlier detection**

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sns.set_style('whitegrid')

# %% [markdown]
# **Visually inspecting Boxplots**

# %%
import pandas as pd
import matplotlib.pyplot as plt

address = '/content/iris_data.csv'

# Read CSV file
df = pd.read_csv(address)

# Rename columns if necessary
df.columns = ['sepal Length', 'sepal Width', 'Petal Length', 'Petal Width', 'species']

# Features and target
x = df.iloc[:, 0:4].values
y = df.iloc[:, 4].values

# Display the first 5 rows
print(df.head())
# Out:
#    sepal Length  sepal Width  Petal Length  Petal Width species
# 0           4.9          3.0           1.4          0.2  setosa
# 1           4.7          3.2           1.3          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='species', y='sepal Length', data=df, hue='species', palette='hls')
plt.title('Boxplot of Sepal Length by Species')
plt.show()

# %% [markdown]
# **Looking at the sctterplot matrix**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df, hue='species', palette='hls')
plt.show()

# %% [markdown]
# **Applying Tukey Outlier labeling**

# %%
pd.options.display.float_format = '{:.1f}'.format
x_df = pd.DataFrame(x)
print(x_df.describe())
# Out:
#           0     1     2     3
# count 149.0 149.0 149.0 149.0
# mean    5.8   3.1   3.8   1.2
# std     0.8   0.4   1.8   0.8
# min     4.3   2.0   1.0   0.1
# 25%     5.1   2.8   1.6   0.3
# 50%     5.8   3.0   4.4   1.3
# 75%     6.4   3.3   5.1   1.8
# max     7.9   4.4   6.9   2.5
