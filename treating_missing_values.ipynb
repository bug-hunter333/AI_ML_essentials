# %% [markdown]
# <a href="https://colab.research.google.com/github/bug-hunter333/Begineer-coding-projects/blob/main/treating_missing_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Working With Missing Data In Pandas

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame

# %% [markdown]
# Filling missing values using fillna(),replace() and interpolate

# %%
data = {'names':['steve','john','sarah','richard','lomu','michael'],
        'age':[20,22,20,21,19,23],
        'gender':['M','M','F','M','M','M'],
        'rank':[2,1,4,5,6,7]}

ranking_df = DataFrame(data)
ranking_df.iloc[2:5,1] = np.nan
ranking_df.iloc[0:3,3] = np.nan
ranking_df.iloc[3,:]=np.nan
ranking_df
# Out:
#      names   age gender  rank
# 0    steve  20.0      M   NaN
# 1     john  22.0      M   NaN
# 2    sarah   NaN      F   NaN
# 3      NaN   NaN    NaN   NaN
# 4     lomu   NaN      M   6.0
# 5  michael  23.0      M   7.0

# %%
ranking_df.isnull()
# Out:
#    names    age  gender   rank
# 0  False  False   False   True
# 1  False  False   False   True
# 2  False   True   False   True
# 3   True   True    True   True
# 4  False   True   False  False
# 5  False  False   False  False

# %%
ranking_df.notnull()
# Out:
#    names    age  gender   rank
# 0   True   True    True  False
# 1   True   True    True  False
# 2   True  False    True  False
# 3  False  False   False  False
# 4   True  False    True   True
# 5   True   True    True   True

# %%
bool_series = pd.isnull(ranking_df['age'])
ranking_df[bool_series]
# Out:
#    names  age gender  rank
# 2  sarah  NaN      F   NaN
# 3    NaN  NaN    NaN   NaN
# 4   lomu  NaN      M   6.0

# %%
ranking_df.fillna(0)
# Out:
#      names   age gender  rank
# 0    steve  20.0      M   0.0
# 1     john  22.0      M   0.0
# 2    sarah   0.0      F   0.0
# 3        0   0.0      0   0.0
# 4     lomu   0.0      M   6.0
# 5  michael  23.0      M   7.0

# %%
ranking_df.fillna(method='pad')
# Out:
# /tmp/ipython-input-8-2647120121.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ranking_df.fillna(method='pad')
#      names   age gender  rank
# 0    steve  20.0      M   NaN
# 1     john  22.0      M   NaN
# 2    sarah  22.0      F   NaN
# 3    sarah  22.0      F   NaN
# 4     lomu  22.0      M   6.0
# 5  michael  23.0      M   7.0

# %%
ranking_df.fillna(method='bfill')
# Out:
# /tmp/ipython-input-9-3253257716.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ranking_df.fillna(method='bfill')
#      names   age gender  rank
# 0    steve  20.0      M   6.0
# 1     john  22.0      M   6.0
# 2    sarah  23.0      F   6.0
# 3     lomu  23.0      M   6.0
# 4     lomu  23.0      M   6.0
# 5  michael  23.0      M   7.0

# %%
ranking_df.interpolate(method='linear')
# Out:
# /tmp/ipython-input-10-2827130586.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   ranking_df.interpolate(method='linear')
#      names    age gender  rank
# 0    steve  20.00      M   NaN
# 1     john  22.00      M   NaN
# 2    sarah  22.25      F   NaN
# 3      NaN  22.50    NaN   NaN
# 4     lomu  22.75      M   6.0
# 5  michael  23.00      M   7.0

# %%
ranking_df.dropna()
# Out:
#      names   age gender  rank
# 5  michael  23.0      M   7.0

# %%
ranking_df.dropna(how='all')
# Out:
#      names   age gender  rank
# 0    steve  20.0      M   NaN
# 1     john  22.0      M   NaN
# 2    sarah   NaN      F   NaN
# 4     lomu   NaN      M   6.0
# 5  michael  23.0      M   7.0

# %%
ranking_df.dropna(axis=0)
# Out:
#      names   age gender  rank
# 5  michael  23.0      M   7.0

# %%
ranking_df.dropna(thresh=2)
# Out:
#      names   age gender  rank
# 0    steve  20.0      M   NaN
# 1     john  22.0      M   NaN
# 2    sarah   NaN      F   NaN
# 4     lomu   NaN      M   6.0
# 5  michael  23.0      M   7.0
