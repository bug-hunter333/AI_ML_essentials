# %% [markdown]
# <a href="https://colab.research.google.com/github/bug-hunter333/AI_ML_essentials/blob/main/extreme_value_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Extreme value analysis for outliers**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 14,7
sns.set_style('whitegrid')

# %%
import pandas as pd
import matplotlib.pyplot as plt

address = '/content/iris_data.csv'

# Read CSV file
df = pd.read_csv(address)

# Rename columns if necessary
df.columns = ['sepal Length', 'sepal Width', 'Petal Length', 'Petal Width', 'species']

# Features and target
x = df.iloc[:, 0:4].values
y = df.iloc[:, 4].values

# Display the first 5 rows
print(df.head())
# Out:
#    sepal Length  sepal Width  Petal Length  Petal Width species
# 0           4.9          3.0           1.4          0.2  setosa
# 1           4.7          3.2           1.3          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %% [markdown]
# Identifying Outliers from tukey Boxplot

# %%
df.boxplot(return_type = 'dict')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
Sepal_width = x[:,1]
iris_outliers = (Sepal_width > 4)
df[iris_outliers]
# Out:
#     sepal Length  sepal Width  Petal Length  Petal Width species
# 14           5.7          4.4           1.5          0.4  setosa
# 31           5.2          4.1           1.5          0.1  setosa
# 32           5.5          4.2           1.4          0.2  setosa

# %%
Sepal_width = x[:,1]
iris_outliers = (Sepal_width < 2.05)
df[iris_outliers]
# Out:
#     sepal Length  sepal Width  Petal Length  Petal Width     species
# 59           5.0          2.0           3.5          1.0  versicolor

# %% [markdown]
# **Applying Tukey outlier Labeling**

# %%
import pandas as pd

# Optional: Set float format
pd.options.display.float_format = '{:.1f}'.format

# Convert x to DataFrame
X_df = pd.DataFrame(x, columns=['sepal Length', 'sepal Width', 'Petal Length', 'Petal Width'])

# Summary statistics
print(X_df.describe())
# Out:
#        sepal Length  sepal Width  Petal Length  Petal Width
# count         149.0        149.0         149.0        149.0
# mean            5.8          3.1           3.8          1.2
# std             0.8          0.4           1.8          0.8
# min             4.3          2.0           1.0          0.1
# 25%             5.1          2.8           1.6          0.3
# 50%             5.8          3.0           4.4          1.3
# 75%             6.4          3.3           5.1          1.8
# max             7.9          4.4           6.9          2.5
